# %%
import scib
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# The data was taken from here https://figshare.com/articles/dataset/Benchmarking_atlas-level_data_integration_in_single-cell_genomics_-_integration_task_datasets_Immune_and_pancreas_/12420968

# %%
# !wget -O data/human_pancreas_norm_complexBatch.h5ad https://figshare.com/ndownloader/files/24539828
# Out:
# --2023-03-14 20:52:54--  https://figshare.com/ndownloader/files/24539828
# Resolving figshare.com (figshare.com)... 34.240.113.119, 54.229.56.157, 2a05:d018:1f4:d000:8f2d:b761:e885:37ef, ...
# Connecting to figshare.com (figshare.com)|34.240.113.119|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/24539828/human_pancreas_norm_complexBatch.h5ad?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20230314/eu-west-1/s3/aws4_request&X-Amz-Date=20230314T205254Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=76c37be3119839c95057773c26add2ec30a270ebd639929854b28ccbd2548a69 [following]
# --2023-03-14 20:52:54--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/24539828/human_pancreas_norm_complexBatch.h5ad?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20230314/eu-west-1/s3/aws4_request&X-Amz-Date=20230314T205254Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=76c37be3119839c95057773c26add2ec30a270ebd639929854b28ccbd2548a69
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.109.203, 52.218.116.248, 52.218.91.19, ...
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.109.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 315955785 (301M) [application/octet-stream]
# Saving to: ‘data/human_pancreas_norm_complexBatch.h5ad’
#
# data/human_pancreas 100%[===================>] 301.32M  99.5MB/s    in 3.0s
#
# 2023-03-14 20:52:57 (99.5 MB/s) - ‘data/human_pancreas_norm_complexBatch.h5ad’ saved [315955785/315955785]

# %%
adata = sc.read('data/human_pancreas_norm_complexBatch.h5ad')
adata
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/h5ad.py:238: OldFormatWarning: Element '/X' was written without encoding metadata.
#   d[k] = read_elem(f[k])
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/h5ad.py:238: OldFormatWarning: Element '/layers' was written without encoding metadata.
#   d[k] = read_elem(f[k])
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:92: OldFormatWarning: Element '/layers/counts' was written without encoding metadata.
#   return {k: read_elem(v) for k, v in elem.items()}
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:584: OldFormatWarning: Element '/obs/__categories/tech' was written without encoding metadata.
#   categories = read_elem(categories_dset)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:587: OldFormatWarning: Element '/obs/tech' was written without encoding metadata.
#   read_elem(dataset), categories, ordered=ordered
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:584: OldFormatWarning: Element '/obs/__categories/celltype' was written without encoding metadata.
#   categories = read_elem(categories_dset)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:587: OldFormatWarning: Element '/obs/celltype' was written without encoding metadata.
#   read_elem(dataset), categories, ordered=ordered
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/size_factors' was written without encoding metadata.
#   return read_elem(dataset)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/_index' was written without encoding metadata.
#   return read_elem(dataset)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/var/_index' was written without encoding metadata.
#   return read_elem(dataset)
# AnnData object with n_obs × n_vars = 16382 × 19093
#     obs: 'tech', 'celltype', 'size_factors'
#     layers: 'counts'

# %%
adata.X
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [2.6120808 , 0.        , 0.        , ..., 0.        , 2.6120806 ,
#         0.        ],
#        [0.        , 3.311074  , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.42996258, 2.6206095 , 0.        , ..., 2.1124895 , 1.0953737 ,
#         1.0403827 ],
#        [3.4695568 , 0.64595073, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.4566651 , 0.5159923 , 0.        , ..., 0.        , 0.53929645,
#         0.        ]], dtype=float32)

# %%
adata.obs
# Out:
#                 tech celltype  size_factors
# D101_5        celseq    gamma      0.028492
# D101_43       celseq    gamma      0.079348
# D101_93       celseq    gamma      0.037932
# D102_4        celseq    gamma      0.047685
# D172444_23    celseq    gamma      0.038683
# ...              ...      ...           ...
# Sample_1594  smarter    gamma      1.000000
# Sample_1595  smarter    gamma      1.000000
# Sample_1597  smarter    gamma      1.000000
# Sample_1598  smarter    gamma      1.000000
# Sample_1600  smarter    gamma      1.000000
#
# [16382 rows x 3 columns]

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [A1BG, A1CF, A2M, A2ML1, A4GALT, A4GNT, AA06, AAAS, AACS, AACSP1, AADAC, AADACL2, AADACL3, AADAT, AAED1, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS2, AARSD1, AASDH, AASDHPPT, AASS, AATF, AATK, ABAT, ABCA1, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA17P, ABCA2, ABCA3, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCB1, ABCB10, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC13, ABCC2, ABCC3, ABCC4, ABCC5, ABCC6, ABCC6P1, ABCC6P2, ABCC8, ABCC9, ABCD1, ABCD2, ABCD3, ABCD4, ABCE1, ABCF1, ABCF2, ABCF3, ABCG1, ABCG2, ABCG4, ABCG5, ABCG8, ABHD1, ABHD10, ABHD11, ABHD12, ABHD12B, ABHD13, ABHD14A, ABHD14B, ABHD15, ABHD16A, ABHD16B, ABHD17A, ABHD17B, ABHD17C, ABHD2, ABHD3, ABHD4, ABHD5, ABHD6, ...]
#
# [19093 rows x 0 columns]

# %%
adata.layers['counts']
# Out:
# array([[ 0.       ,  0.       ,  0.       , ...,  0.       ,  0.       ,
#          0.       ],
#        [ 1.0019583,  0.       ,  0.       , ...,  0.       ,  1.001958 ,
#          0.       ],
#        [ 0.       ,  1.0019583,  0.       , ...,  0.       ,  0.       ,
#          0.       ],
#        ...,
#        [ 0.5372   , 12.7441   ,  0.       , ...,  7.2688   ,  1.9903   ,
#          1.8303   ],
#        [31.1225   ,  0.9078   ,  0.       , ...,  0.       ,  0.       ,
#          0.       ],
#        [ 0.5788   ,  0.6753   ,  0.       , ...,  0.       ,  0.7148   ,
#          0.       ]], dtype=float32)

# %%
pd.crosstab(adata.obs.tech,adata.obs.celltype)
# Out:
# celltype    acinar  activated_stellate  alpha  beta  delta  ductal  \
# tech
# celseq         228                  19    191   161     50     327
# celseq2        274                  90    843   445    203     258
# fluidigmc1      21                  16    239   258     25      36
# inDrop1        110                  51    236   872    214     120
# inDrop2          3                  81    676   371    125     301
# inDrop3        843                 100   1130   787    161     376
# inDrop4          2                  52    284   495    101     280
# smarter          0                   0    886   472     49       0
# smartseq2      188                  55   1008   308    127     444
#
# celltype    endothelial  epsilon  gamma  macrophage  mast  quiescent_stellate  \
# tech
# celseq                5        1     18           1     1                   1
# celseq2              21        4    110          15     6                  12
# fluidigmc1           14        1     18           1     3                   1
# inDrop1             130       13     70          14     8                  92
# inDrop2              23        2     86          17     9                  22
# inDrop3              92        2     36          14     7                  54
# inDrop4               7        1     63          10     1                   5
# smarter               0        0     85           0     0                   0
# smartseq2            21        8    213           7     7                   6
#
# celltype    schwann  t_cell
# tech
# celseq            1       0
# celseq2           4       0
# fluidigmc1        5       0
# inDrop1           5       2
# inDrop2           6       2
# inDrop3           1       2
# inDrop4           1       1
# smarter           0       0
# smartseq2         2       0

# %% [markdown]
# # UMAP without integration

# %%
plt.hist(adata.X.flatten())
# Out:
# (array([2.65111869e+08, 1.49635120e+07, 2.11839980e+07, 9.37415500e+06,
#         1.80255000e+06, 2.86991000e+05, 3.87650000e+04, 1.37910000e+04,
#         4.94900000e+03, 9.46000000e+02]),
#  array([ 0.        ,  1.3002677 ,  2.60053539,  3.90080309,  5.20107079,
#          6.50133848,  7.80160618,  9.1018734 , 10.40214157, 11.70240974,
#         13.00267696]),
#  <BarContainer object of 10 artists>)

# %%
sc.pp.highly_variable_genes(adata)
adata.var.highly_variable.value_counts()
# Out:
# False    15548
# True      3545
# Name: highly_variable, dtype: int64

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata = adata[:, adata.var.highly_variable]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 16382 × 3545
#     obs: 'tech', 'celltype', 'size_factors'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg'
#     layers: 'counts'

# %%
sc.pp.scale(adata)
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_simple.py:843: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
sc.tl.pca(adata)

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.neighbors(adata,n_neighbors=15, n_pcs=50)

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata,color=['tech', 'celltype'])
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:163: PendingDeprecationWarning: The get_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = copy(get_cmap(cmap))
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # scib

# %% [markdown]
# ## Preprocessing
# according to https://github.com/theislab/scib-reproducibility/tree/main/notebooks/data_preprocessing/pancreas the data is already normalazed and log-transformed so we will skip scib.preprocessing.normalize

# %%
adata = sc.read('data/human_pancreas_norm_complexBatch.h5ad')
adata
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/h5ad.py:238: OldFormatWarning: Element '/X' was written without encoding metadata.
#   d[k] = read_elem(f[k])
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/h5ad.py:238: OldFormatWarning: Element '/layers' was written without encoding metadata.
#   d[k] = read_elem(f[k])
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:92: OldFormatWarning: Element '/layers/counts' was written without encoding metadata.
#   return {k: read_elem(v) for k, v in elem.items()}
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:584: OldFormatWarning: Element '/obs/__categories/tech' was written without encoding metadata.
#   categories = read_elem(categories_dset)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:587: OldFormatWarning: Element '/obs/tech' was written without encoding metadata.
#   read_elem(dataset), categories, ordered=ordered
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:584: OldFormatWarning: Element '/obs/__categories/celltype' was written without encoding metadata.
#   categories = read_elem(categories_dset)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:587: OldFormatWarning: Element '/obs/celltype' was written without encoding metadata.
#   read_elem(dataset), categories, ordered=ordered
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/size_factors' was written without encoding metadata.
#   return read_elem(dataset)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/_index' was written without encoding metadata.
#   return read_elem(dataset)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/var/_index' was written without encoding metadata.
#   return read_elem(dataset)
# AnnData object with n_obs × n_vars = 16382 × 19093
#     obs: 'tech', 'celltype', 'size_factors'
#     layers: 'counts'

# %%
# scib modifies bath column at least in scib.preprocessing.scale_batch to integer, so I make a copy to have text representation
adata.obs['tech_text'] = adata.obs.tech

# %%
ccscores = scib.preprocessing.score_cell_cycle(adata,'human')
adata.obs
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):
#                 tech celltype  size_factors tech_text   S_score  G2M_score  \
# D101_5        celseq    gamma      0.028492    celseq  0.050221  -0.422348
# D101_43       celseq    gamma      0.079348    celseq  0.012194  -0.536017
# D101_93       celseq    gamma      0.037932    celseq -0.022595   0.015658
# D102_4        celseq    gamma      0.047685    celseq  0.128670  -0.260789
# D172444_23    celseq    gamma      0.038683    celseq -0.041654  -0.394326
# ...              ...      ...           ...       ...       ...        ...
# Sample_1594  smarter    gamma      1.000000   smarter  0.252066  -0.508501
# Sample_1595  smarter    gamma      1.000000   smarter  0.090100  -0.388399
# Sample_1597  smarter    gamma      1.000000   smarter  0.027931  -0.461743
# Sample_1598  smarter    gamma      1.000000   smarter  0.013514  -0.207898
# Sample_1600  smarter    gamma      1.000000   smarter -0.198831  -0.263792
#
#             phase
# D101_5          S
# D101_43         S
# D101_93       G2M
# D102_4          S
# D172444_23     G1
# ...           ...
# Sample_1594     S
# Sample_1595     S
# Sample_1597     S
# Sample_1598     S
# Sample_1600    G1
#
# [16382 rows x 7 columns]

# %%
#lets check per gene sd
plt.hist(np.std(adata.X,axis=0))
# Out:
# (array([6.310e+03, 2.969e+03, 3.575e+03, 3.393e+03, 2.431e+03, 3.420e+02,
#         5.300e+01, 1.400e+01, 4.000e+00, 2.000e+00]),
#  array([0.        , 0.37460446, 0.74920893, 1.12381339, 1.49841785,
#         1.87302232, 2.24762678, 2.62223125, 2.99683571, 3.37144017,
#         3.74604464]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.std(adata.X[adata.obs.tech_text=='inDrop1',:],axis=0))
# Out:
# (array([6414., 2386., 2341., 2511., 2078., 1542., 1241.,  521.,   47.,
#           12.]),
#  array([0.        , 0.28488523, 0.56977046, 0.85465562, 1.13954091,
#         1.42442608, 1.70931125, 1.99419653, 2.27908182, 2.56396699,
#         2.84885216]),
#  <BarContainer object of 10 artists>)

# %%
 adata = scib.preprocessing.scale_batch(adata, 'tech')
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],

# %%
#lets check per gene sd
plt.hist(np.std(adata.X,axis=0))
# Out:
# (array([  322.,    72.,    68.,   475.,   449.,   593.,   641.,   559.,
#           969., 14945.]),
#  array([0.        , 0.09998442, 0.19996884, 0.29995325, 0.39993769,
#         0.4999221 , 0.5999065 , 0.69989091, 0.79987538, 0.89985979,
#         0.99984419]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.std(adata.X[adata.obs.tech_text=='inDrop1',:],axis=0,ddof=1))
# Out:
# (array([ 3518.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#             0., 15575.]),
#  array([0.        , 0.10000277, 0.20000553, 0.3000083 , 0.40001106,
#         0.50001383, 0.60001659, 0.70001936, 0.80002213, 0.90002489,
#         1.00002766]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter((adata.X[adata.obs.tech_text=='inDrop1',:]>0).sum(0),np.std(adata.X[adata.obs.tech_text=='inDrop1',:],axis=0,ddof=1))

# %%
adata = scib.preprocessing.hvg_batch(
                adata,
                batch_key='tech',
                adataOut=True)
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hvg = hvg.append(missing_hvg, ignore_index=True)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hvg = hvg.append(missing_hvg, ignore_index=True)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hvg = hvg.append(missing_hvg, ignore_index=True)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hvg = hvg.append(missing_hvg, ignore_index=True)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hvg = hvg.append(missing_hvg, ignore_index=True)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hvg = hvg.append(missing_hvg, ignore_index=True)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hvg = hvg.append(missing_hvg, ignore_index=True)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hvg = hvg.append(missing_hvg, ignore_index=True)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hvg = hvg.append(missing_hvg, ignore_index=True)
# Using 0 HVGs from full intersect set
# Using 0 HVGs from n_batch-1 set
# Using 0 HVGs from n_batch-2 set
# Using 6 HVGs from n_batch-3 set
# Using 44 HVGs from n_batch-4 set
# Using 195 HVGs from n_batch-5 set
# Using 1065 HVGs from n_batch-6 set
# Using 690 HVGs from n_batch-7 set
# Using 2000 HVGs

# %% [markdown]
# ## integration
# ### no

# %%
adata_no = adata.copy()
sc.tl.pca(adata_no)
sc.pp.neighbors(adata_no,n_neighbors=15, n_pcs=50)
sc.tl.umap(adata_no)

# %%
scib.me.cluster_optimal_resolution(adata_no, cluster_key="cluster", label_key="celltype")
adata_no.obs
# Out:
# resolution: 0.1, nmi: 0.7208448241183698
# resolution: 0.2, nmi: 0.76396484069035
# resolution: 0.3, nmi: 0.765960587798711
# resolution: 0.4, nmi: 0.7354679431959457
# resolution: 0.5, nmi: 0.72311606496152
# resolution: 0.6, nmi: 0.7301633908018414
# resolution: 0.7, nmi: 0.6991665225866686
# resolution: 0.8, nmi: 0.6904855719789011
# resolution: 0.9, nmi: 0.6839120565567994
# resolution: 1.0, nmi: 0.669332586483522
# resolution: 1.1, nmi: 0.6620408191399881
# resolution: 1.2, nmi: 0.6595490668035345
# resolution: 1.3, nmi: 0.6497699760265455
# resolution: 1.4, nmi: 0.6430127319030803
# resolution: 1.5, nmi: 0.6366347251432609
# resolution: 1.6, nmi: 0.6252177976729207
# resolution: 1.7, nmi: 0.618986018451193
# resolution: 1.8, nmi: 0.6197793606422857
# resolution: 1.9, nmi: 0.6160640470731844
# resolution: 2.0, nmi: 0.6164870019198668
# optimised clustering against celltype
# optimal cluster resolution: 0.3
# optimal score: 0.765960587798711
#             tech celltype  size_factors tech_text   S_score  G2M_score phase  \
# D101_5         0    gamma      0.028492    celseq  0.050221  -0.422348     S
# D101_43        0    gamma      0.079348    celseq  0.012194  -0.536017     S
# D101_93        0    gamma      0.037932    celseq -0.022595   0.015658   G2M
# D102_4         0    gamma      0.047685    celseq  0.128670  -0.260789     S
# D172444_23     0    gamma      0.038683    celseq -0.041654  -0.394326    G1
# ...          ...      ...           ...       ...       ...        ...   ...
# Sample_1594    7    gamma      1.000000   smarter  0.252066  -0.508501     S
# Sample_1595    7    gamma      1.000000   smarter  0.090100  -0.388399     S
# Sample_1597    7    gamma      1.000000   smarter  0.027931  -0.461743     S
# Sample_1598    7    gamma      1.000000   smarter  0.013514  -0.207898     S
# Sample_1600    7    gamma      1.000000   smarter -0.198831  -0.263792    G1
#
#             cluster
# D101_5            4
# D101_43           4
# D101_93           4
# D102_4            4
# D172444_23        0
# ...             ...
# Sample_1594       4
# Sample_1595       4
# Sample_1597       4
# Sample_1598       0
# Sample_1600       4
#
# [16382 rows x 8 columns]

# %%
sc.pl.umap(adata_no,color=['tech', 'celltype','cluster'])
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:163: PendingDeprecationWarning: The get_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = copy(get_cmap(cmap))
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### bbknn

# %%
adata_bbknn = scib.ig.bbknn(adata.copy(), batch="tech")
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/bbknn/__init__.py:294: FutureWarning: This location for 'distances' is deprecated. It has been moved to .obsp[distances], and will not be accesible here in a future version of anndata.
#   adata.uns['neighbors']['distances'] = bbknn_out[0]
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/bbknn/__init__.py:295: FutureWarning: This location for 'connectivities' is deprecated. It has been moved to .obsp[connectivities], and will not be accesible here in a future version of anndata.
#   adata.uns['neighbors']['connectivities'] = bbknn_out[1]

# %%
adata_bbknn
# Out:
# AnnData object with n_obs × n_vars = 16382 × 2000
#     obs: 'tech', 'celltype', 'size_factors', 'tech_text', 'S_score', 'G2M_score', 'phase'
#     var: 'mean-0', 'std-0', 'mean-1', 'std-1', 'mean-2', 'std-2', 'mean-3', 'std-3', 'mean-4', 'std-4', 'mean-5', 'std-5', 'mean-6', 'std-6', 'mean-7', 'std-7', 'mean-8', 'std-8', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'hvg', 'pca', 'neighbors'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'distances', 'connectivities'

# %%
sc.tl.umap(adata_bbknn)

# %% [markdown]
# compare with https://theislab.github.io/scib-reproducibility/dataset_pancreas.html#3_Embeddings

# %%
scib.me.cluster_optimal_resolution(adata_bbknn, cluster_key="cluster", label_key="celltype")
adata_bbknn.obs
# Out:
# resolution: 0.1, nmi: 0.7043371337989133
# resolution: 0.2, nmi: 0.8104329913797663
# resolution: 0.3, nmi: 0.808759846792489
# resolution: 0.4, nmi: 0.7609991910843158
# resolution: 0.5, nmi: 0.726643911673302
# resolution: 0.6, nmi: 0.7266386965250674
# resolution: 0.7, nmi: 0.7299582635555363
# resolution: 0.8, nmi: 0.7348060822038128
# resolution: 0.9, nmi: 0.723610054478954
# resolution: 1.0, nmi: 0.736975728875121
# resolution: 1.1, nmi: 0.702680917558232
# resolution: 1.2, nmi: 0.6956512280370909
# resolution: 1.3, nmi: 0.6991306051294972
# resolution: 1.4, nmi: 0.6935332438646195
# resolution: 1.5, nmi: 0.6871684232913624
# resolution: 1.6, nmi: 0.6867574938302807
# resolution: 1.7, nmi: 0.6891614833175999
# resolution: 1.8, nmi: 0.6801914907257582
# resolution: 1.9, nmi: 0.6705413045700293
# resolution: 2.0, nmi: 0.6766643821531698
# optimised clustering against celltype
# optimal cluster resolution: 0.2
# optimal score: 0.8104329913797663
#             tech celltype  size_factors tech_text   S_score  G2M_score phase  \
# D101_5         0    gamma      0.028492    celseq  0.050221  -0.422348     S
# D101_43        0    gamma      0.079348    celseq  0.012194  -0.536017     S
# D101_93        0    gamma      0.037932    celseq -0.022595   0.015658   G2M
# D102_4         0    gamma      0.047685    celseq  0.128670  -0.260789     S
# D172444_23     0    gamma      0.038683    celseq -0.041654  -0.394326    G1
# ...          ...      ...           ...       ...       ...        ...   ...
# Sample_1594    7    gamma      1.000000   smarter  0.252066  -0.508501     S
# Sample_1595    7    gamma      1.000000   smarter  0.090100  -0.388399     S
# Sample_1597    7    gamma      1.000000   smarter  0.027931  -0.461743     S
# Sample_1598    7    gamma      1.000000   smarter  0.013514  -0.207898     S
# Sample_1600    7    gamma      1.000000   smarter -0.198831  -0.263792    G1
#
#             cluster
# D101_5            4
# D101_43           4
# D101_93           4
# D102_4            4
# D172444_23        0
# ...             ...
# Sample_1594       4
# Sample_1595       4
# Sample_1597       4
# Sample_1598       0
# Sample_1600       4
#
# [16382 rows x 8 columns]

# %%
sc.pl.umap(adata_bbknn,color=['tech', 'celltype','cluster'])
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:163: PendingDeprecationWarning: The get_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = copy(get_cmap(cmap))
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # Metrics

# %%
integrated = {'no':adata_no,'bbknn':adata_bbknn}

# %% [markdown]
# ## ARI

# %%
{k:scib.me.ari(integrated[k], cluster_key="cluster", label_key="celltype") for k in integrated.keys()}
# Out:
# {'no': 0.7857627152860657, 'bbknn': 0.8569713577103358}

# %% [markdown]
# ## NMI

# %%
{k:scib.me.nmi(integrated[k], cluster_key="cluster", label_key="celltype") for k in integrated.keys()}
# Out:
# {'no': 0.7659605877987111, 'bbknn': 0.8104329913797663}

# %% [markdown]
# ## cLISI

# %%
{k:scib.me.clisi_graph(integrated[k],label_key="celltype",type_='knn',k0=15) for k in integrated.keys()}
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o: /usr/lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o: /usr/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [158], in <cell line: 1>()
# ----> 1 {k:scib.me.clisi_graph(integrated[k],label_key="celltype",type_='knn',k0=15) for k in integrated.keys()}
#
# Input In [158], in <dictcomp>(.0)
# ----> 1 {k:scib.me.clisi_graph(integrated[k],label_key="celltype",type_='knn',k0=15) for k in integrated.keys()}
#
# File ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py:182, in clisi_graph(adata, label_key, type_, use_rep, batch_key, k0, subsample, scale, n_cores, verbose)
#     178 check_batch(label_key, adata.obs)
#     180 adata_tmp = recompute_knn(adata, type_, use_rep)
# --> 182 scores = lisi_graph_py(
#     183     adata=adata_tmp,
#     184     obs_key=label_key,
#     185     n_neighbors=k0,
#     186     perplexity=None,
#     187     subsample=subsample,
#     188     n_cores=n_cores,
#     189     verbose=verbose,
#     190 )
#     192 # cLISI: 1 good, nlabs bad
#     193 clisi = np.nanmedian(scores)
#
# File ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py:331, in lisi_graph_py(adata, obs_key, n_neighbors, perplexity, subsample, n_cores, verbose)
#     328     simpson_estimate_batch = np.concatenate(results)
#     330 else:
# --> 331     simpson_estimate_batch = compute_simpson_index_graph(
#     332         file_prefix=prefix,
#     333         batch_labels=batch,
#     334         n_batches=n_batches,
#     335         perplexity=perplexity,
#     336         n_neighbors=n_neighbors,
#     337     )
#     339 tmpdir.cleanup()
#     341 return 1 / simpson_estimate_batch
#
# File ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py:445, in compute_simpson_index_graph(file_prefix, batch_labels, n_batches, n_neighbors, perplexity, chunk_no, tol)
#     442 logU = np.log(perplexity)
#     444 # check if the target file is not empty
# --> 445 if os.stat(index_file).st_size == 0:
#     446     print("File has no entries. Doing nothing.")
#     447     lists = np.zeros(0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/lisi__t3oqef3/graph_lisi_indices_0.txt'

# %%
# ?scib.me.clisi_graph
# Out:
# Signature:
# scib.me.clisi_graph(
#     adata,
#     label_key,
#     type_,
#     use_rep='X_emb',
#     batch_key=None,
#     k0=90,
#     subsample=None,
#     scale=True,
#     n_cores=1,
#     verbose=False,
# )
# Docstring:
# Cell-type LISI (cLISI) score
#
# Local Inverse Simpson’s Index metrics adapted from `Korsunsky et al. 2019`_ to run on all full
# feature, embedding and kNN integration outputs via shortest path-based distance computation on single-cell kNN
# graphs.
# By default, this function returns a value scaled between 0 and 1 instead of the original LISI range of 0 to the
# number of labels.
#
# .. _Korsunsky et al. 2019: https://doi.org/10.1038/s41592-019-0619-0
#
# :param adata: adata object to calculate on
# :param label_key: label column name in ``adata.obs``
# :param `type_`: type of data integration, one of 'knn', 'embed' or 'full'
# :param use_rep: embedding slot in ``.obsm``, only used for embedding input
# :param batch_key: deprecated, not used
# :param k0: number of nearest neighbors to compute lisi score
#     Please note that the initial neighborhood size that is
#     used to compute shortest paths is 15.
# :param subsample: Percentage of observations (integer between 0 and 100)
#     to which lisi scoring should be subsampled
# :param scale: scale output values between 0 and 1 (True/False)
# :param n_cores: number of cores (i.e. CPUs or CPU cores to use for multiprocessing)
# :return: Median of cLISI scores per cell type labels
#
# This function can be applied to all integration output types and recomputes the kNN graph for feature and embedding
# output with specific parameters.
# Thus, no preprocessing is required, but the correct output type must be specified in ``type_``.
#
# **Examples**
#
# .. code-block:: python
#
#     # feature output or unintegrated object
#     scib.me.clisi_graph(adata, label_key="celltype", type="full")
#
#     # embeding output
#     scib.me.clisi_graph(adata, label_key="celltype", type="embed", use_rep="X_emb")
#
#     # knn output
#     scib.me.clisi_graph(adata, label_key="celltype", type="knn")
# File:      ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py
# Type:      function

# %%
scib.me.clisi_graph(adata_no,label_key="celltype",type_='knn')
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o: /usr/lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o: /usr/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [154], in <cell line: 1>()
# ----> 1 scib.me.clisi_graph(adata_no,label_key="celltype",type_='knn')
#
# File ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py:182, in clisi_graph(adata, label_key, type_, use_rep, batch_key, k0, subsample, scale, n_cores, verbose)
#     178 check_batch(label_key, adata.obs)
#     180 adata_tmp = recompute_knn(adata, type_, use_rep)
# --> 182 scores = lisi_graph_py(
#     183     adata=adata_tmp,
#     184     obs_key=label_key,
#     185     n_neighbors=k0,
#     186     perplexity=None,
#     187     subsample=subsample,
#     188     n_cores=n_cores,
#     189     verbose=verbose,
#     190 )
#     192 # cLISI: 1 good, nlabs bad
#     193 clisi = np.nanmedian(scores)
#
# File ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py:331, in lisi_graph_py(adata, obs_key, n_neighbors, perplexity, subsample, n_cores, verbose)
#     328     simpson_estimate_batch = np.concatenate(results)
#     330 else:
# --> 331     simpson_estimate_batch = compute_simpson_index_graph(
#     332         file_prefix=prefix,
#     333         batch_labels=batch,
#     334         n_batches=n_batches,
#     335         perplexity=perplexity,
#     336         n_neighbors=n_neighbors,
#     337     )
#     339 tmpdir.cleanup()
#     341 return 1 / simpson_estimate_batch
#
# File ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py:445, in compute_simpson_index_graph(file_prefix, batch_labels, n_batches, n_neighbors, perplexity, chunk_no, tol)
#     442 logU = np.log(perplexity)
#     444 # check if the target file is not empty
# --> 445 if os.stat(index_file).st_size == 0:
#     446     print("File has no entries. Doing nothing.")
#     447     lists = np.zeros(0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/lisi_ezy9bwru/graph_lisi_indices_0.txt'

# %%
adata_no.uns['neighbors']
# Out:
# OverloadedDict, wrapping:
# 	{'connectivities_key': 'connectivities', 'distances_key': 'distances', 'params': {'n_neighbors': 15, 'method': 'umap', 'random_state': 0, 'metric': 'euclidean', 'n_pcs': 50}}
# With overloaded keys:
# 	['connectivities', 'distances'].

# %% [markdown]
# ## iLISI

# %%
{k:scib.me.ilisi_graph(integrated[k],batch_key="tech",type_='knn',k0=15) for k in integrated.keys()}
# Out:
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o: /usr/lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o)
# /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o: /usr/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /home/jovyan/my-conda-envs/scnew/lib/python3.10/site-packages/scib/knn_graph/knn_graph.o)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [163], in <cell line: 1>()
# ----> 1 {k:scib.me.ilisi_graph(integrated[k],batch_key="tech",type_='knn',k0=15) for k in integrated.keys()}
#
# Input In [163], in <dictcomp>(.0)
# ----> 1 {k:scib.me.ilisi_graph(integrated[k],batch_key="tech",type_='knn',k0=15) for k in integrated.keys()}
#
# File ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py:100, in ilisi_graph(adata, batch_key, type_, use_rep, k0, subsample, scale, n_cores, verbose)
#      97 check_batch(batch_key, adata.obs)
#      99 adata_tmp = recompute_knn(adata, type_, use_rep)
# --> 100 ilisi_score = lisi_graph_py(
#     101     adata=adata_tmp,
#     102     obs_key=batch_key,
#     103     n_neighbors=k0,
#     104     perplexity=None,
#     105     subsample=subsample,
#     106     n_cores=n_cores,
#     107     verbose=verbose,
#     108 )
#     110 # iLISI: nbatches good, 1 bad
#     111 ilisi = np.nanmedian(ilisi_score)
#
# File ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py:331, in lisi_graph_py(adata, obs_key, n_neighbors, perplexity, subsample, n_cores, verbose)
#     328     simpson_estimate_batch = np.concatenate(results)
#     330 else:
# --> 331     simpson_estimate_batch = compute_simpson_index_graph(
#     332         file_prefix=prefix,
#     333         batch_labels=batch,
#     334         n_batches=n_batches,
#     335         perplexity=perplexity,
#     336         n_neighbors=n_neighbors,
#     337     )
#     339 tmpdir.cleanup()
#     341 return 1 / simpson_estimate_batch
#
# File ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py:445, in compute_simpson_index_graph(file_prefix, batch_labels, n_batches, n_neighbors, perplexity, chunk_no, tol)
#     442 logU = np.log(perplexity)
#     444 # check if the target file is not empty
# --> 445 if os.stat(index_file).st_size == 0:
#     446     print("File has no entries. Doing nothing.")
#     447     lists = np.zeros(0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/lisi_ji_l7ift/graph_lisi_indices_0.txt'

# %%
# ?scib.me.ilisi_graph
# Out:
# Signature:
# scib.me.ilisi_graph(
#     adata,
#     batch_key,
#     type_,
#     use_rep='X_emb',
#     k0=90,
#     subsample=None,
#     scale=True,
#     n_cores=1,
#     verbose=False,
# )
# Docstring:
# Integration LISI (iLISI) score
#
# Local Inverse Simpson’s Index metrics adapted from `Korsunsky et al. 2019`_ to run on all full
# feature, embedding and kNN integration outputs via shortest path-based distance computation on single-cell kNN
# graphs.
# By default, this function returns a value scaled between 0 and 1 instead of the original LISI range of 0 to the
# number of batches.
#
# .. _Korsunsky et al. 2019: https://doi.org/10.1038/s41592-019-0619-0
#
# :param adata: adata object to calculate on
# :param batch_key: batch column name in ``adata.obs``
# :param `type_`: type of data integration, one of 'knn', 'embed' or 'full'
# :param use_rep: embedding slot in ``.obsm``, only used for embedding input
# :param k0: number of nearest neighbors to compute lisi score
#     Please note that the initial neighborhood size that is
#     used to compute shortest paths is 15.
# :param subsample: Percentage of observations (integer between 0 and 100)
#     to which lisi scoring should be subsampled
# :param scale: scale output values between 0 and 1 (True/False)
# :param n_cores: number of cores (i.e. CPUs or CPU cores to use for multiprocessing)
# :return: Median of iLISI scores per batch labels
#
# This function can be applied to all integration output types and recomputes the kNN graph for feature and embedding
# output with specific parameters.
# Thus, no preprocessing is required, but the correct output type must be specified in ``type_``.
#
# **Examples**
#
# .. code-block:: python
#
#     # feature output or unintegrated object
#     scib.me.ilisi_graph(adata, batch_key="batch", type="full")
#
#     # embeding output
#     scib.me.ilisi_graph(adata, batch_key="batch", type="embed", use_rep="X_emb")
#
#     # knn output
#     scib.me.ilisi_graph(adata, batch_key="batch", type="knn")
# File:      ~/my-conda-envs/scnew/lib/python3.10/site-packages/scib/metrics/lisi.py
# Type:      function

# %%
## kBET

# %%
## Graph connectivity

# %%
## Isolated labels F1

# %%
## Trajectory conservation

# %% [markdown]
# ## cell_cycle
# I'm note really understand what is going on here :) I use umap as ebmedding, that is probably not correct (should be pca smth else with more dimentions)

# %%
{k:scib.me.cell_cycle(adata,integrated[k], batch_key="tech", embed="X_umap",organism='human',recompute_cc=False) for k in integrated.keys()}
# Out:
# {'no': 0.5425455256966862, 'bbknn': 0.696072233113165}
